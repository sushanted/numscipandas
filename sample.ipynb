# %%
import numpy as np

# %%
C = np.array([3,4,5,6,7,6,6,5,4,3,2,1])
print(C)
# Out:
# [3 4 5 6 7 6 6 5 4 3 2 1]

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

plt.plot(C)
plt.show()
